# %%
npm run dev

# %% [markdown]
# nohup with PID saving (recommended):

# %%
cd /workspaces/JS-Playground/repos/Arbit-Frontend/app && nohup npm run dev > /workspaces/JS-Playground/repos/Arbit-Frontend/logs/dev.log 2>&1 & echo $! > /workspaces/JS-Playground/repos/Arbit-Frontend/logs/dev.pid

# %%
jobs -l

# %%
# Stop the server later
kill $(cat /workspaces/JS-Playground/repos/Arbit-Frontend/logs/dev.pid)

# %%
jobs -l
